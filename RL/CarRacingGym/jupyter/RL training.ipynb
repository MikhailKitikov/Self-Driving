# %% [markdown]
# Example 1:

# %%
# !git clone https://github.com/novicasarenac/car-racing-rl.git

# %%
import os
os.chdir('/content/car-racing-rl')

# %%
# !apt-get install -y xvfb x11-utils
# !pip install pyvirtualdisplay==0.2.* \
             PyOpenGL==3.1.* \
             PyOpenGL-accelerate==3.1.*
# !pip install pyglet==1.3.2

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# %%
# !python run.py --train -m=a3c

# %% [markdown]
# Example 2:

# %%
# !pip install --upgrade tensorflow==1.15.0

# %%
# !pip install box2d
# !apt-get install -y xvfb x11-utils
# !pip install pyvirtualdisplay==0.2.* \
             PyOpenGL==3.1.* \
             PyOpenGL-accelerate==3.1.*
# !pip install pyglet==1.3.2

# %%
# !git clone https://github.com/MikhailKitikov/CarRacingGym.git
# Out:
# Cloning into 'CarRacingGym'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 40 (delta 20), reused 32 (delta 12), pack-reused 0
# Unpacking objects: 100% (40/40), done.

# %%
import os
os.chdir('/content/CarRacingGym')

# %%
# import shutil
# os.chdir('/content')
# shutil.rmtree('/content/CarRacingGym')

# %%
# import pyvirtualdisplay

# _display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
#                                     size=(1400, 900))
# disp = _display.start()
# !pip install --upgrade gym
# !python training.py -s 1 -e 25 -p 0.1

# %%
start_ep = 1
eps = 1.0
eps_dec = 0.99995**3011
while start_ep + 25 <= 1010:
    import pyvirtualdisplay
    _display = pyvirtualdisplay.Display(visible=False, size=(1400, 900))
    disp = _display.start()
    end_ep = start_ep + 25 - 1
    ckpt = start_ep - 1
    if start_ep == 1:
        # !python training.py -s $start_ep -e $end_ep -p $eps
    else:
        file = 'models/episode_%d.h5' % ckpt
        # !python training.py -s $start_ep -m $file -e $end_ep -p $eps
    start_ep += 25
    if eps > 0.1:
        eps *= eps_dec
# Out:
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2020-12-12 22:09:16.203311: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-12-12 22:09:16.256037: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
start_ep = 1
eps = 1.0
eps_dec = 0.9999**3011
while start_ep + 25 <= 1000:
    import pyvirtualdisplay
    _display = pyvirtualdisplay.Display(visible=False, size=(1400, 900))
    disp = _display.start()
    end_ep = start_ep + 25 - 1
    ckpt = start_ep - 1
    if start_ep == 1:
        # !python training.py -s $start_ep -e $end_ep -p $eps
    else:
        file = 'models/episode_%d.h5' % ckpt
        # !python training.py -s $start_ep -m $file -e $end_ep -p $eps
    start_ep += 25
    if eps > 0.1:
        eps *= eps_dec
# Out:
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2020-12-11 11:42:27.639947: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-12-11 11:42:27.674318: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()
# !python training.py -s 975 -m models/episode_975.h5 -e 1000 -p 0.1
# Out:
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2020-12-11 13:53:45.961072: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-12-11 13:53:45.994872: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
start_ep = 1
eps = 1.0
eps_dec = 0.99995**3011
while start_ep + 25 <= 1010:
    import pyvirtualdisplay
    _display = pyvirtualdisplay.Display(visible=False, size=(1400, 900))
    disp = _display.start()
    end_ep = start_ep + 25 - 1
    ckpt = start_ep - 1
    if start_ep == 1:
        # !python training.py -s $start_ep -e $end_ep -p $eps
    else:
        file = 'models/episode_%d.h5' % ckpt
        # !python training.py -s $start_ep -m $file -e $end_ep -p $eps
    start_ep += 25
    if eps > 0.1:
        eps *= eps_dec
# Out:
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2020-12-12 14:45:57.831932: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-12-12 14:45:57.890561: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %% [markdown]
# hist

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()
# !python training.py -s 1 -e 26

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()
# !python training.py -s 26 -m models/episode_25.h5 -e 51

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()
# !python training.py -s 51 -m models/episode_50.h5 -e 76

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()
# !python training.py -s 76 -m models/episode_75.h5 -e 101

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()
# !python training.py -s 101 -m models/episode_100.h5 -e 126

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 126 -m models/episode_125.h5 -e 151

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 151 -m models/episode_150.h5 -e 176

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 176 -m models/episode_175.h5 -e 201

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 201 -m models/episode_200.h5 -e 226

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 226 -m models/episode_225.h5 -e 251

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 251 -m models/episode_250.h5 -e 276

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 276 -m models/episode_275.h5 -e 301

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 301 -m models/episode_300.h5 -e 326

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 326 -m models/episode_325.h5 -e 351

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 351 -m models/episode_350.h5 -e 376

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 376 -m models/episode_375.h5 -e 401

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 401 -m models/episode_400.h5 -e 426

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 426 -m models/episode_425.h5 -e 451

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 451 -m models/episode_450.h5 -e 476

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 476 -m models/episode_475.h5 -e 501

# %%
import shutil
shutil.copytree('models', '../drive/My Drive/self-driving/dqn_trained/saved_models_noStack_500')
# Out:
# '../drive/My Drive/self-driving/dqn_trained/saved_models_noMem_500'

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 501 -m models/episode_500.h5 -e 526

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 526 -m models/episode_525.h5 -e 551

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 551 -m models/episode_550.h5 -e 576

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 576 -m models/episode_575.h5 -e 601

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 601 -m models/episode_600.h5 -e 626

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 626 -m models/episode_625.h5 -e 651

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 651 -m models/episode_650.h5 -e 676

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 676 -m models/episode_675.h5 -e 701

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 701 -m models/episode_700.h5 -e 726

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 726 -m models/episode_725.h5 -e 751

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 751 -m models/episode_750.h5 -e 776

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 776 -m models/episode_775.h5 -e 801

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 801 -m models/episode_800.h5 -e 826

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 826 -m models/episode_825.h5 -e 851

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 851 -m models/episode_850.h5 -e 876

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 876 -m models/episode_875.h5 -e 901

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 901 -m models/episode_900.h5 -e 926

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 926 -m models/episode_925.h5 -e 951

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 951 -m models/episode_950.h5 -e 976

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
disp = _display.start()

# !python training.py -s 976 -m models/episode_975.h5 -e 1001

# %%
import shutil
shutil.copytree('models', '../drive/My Drive/self-driving/dqn_trained/saved_models_noMem_1000')
# Out:
# '../drive/My Drive/self-driving/dqn_trained/saved_models_noMem_1000'
